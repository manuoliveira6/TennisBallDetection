# %%
import cv2 

cap = cv2.VideoCapture('../input/input_video.mp4')

# %%
frames = []
while True:
    ret, frame = cap.read()
    if not ret:
        break
    frames.append(frame)
cap.release()

# %%
frames
# Out:
# [array([[[ 20,  12,  25],
#          [ 19,  11,  24],
#          [ 18,  10,  23],
#          ...,
#          [ 13,   0,  36],
#          [ 15,   2,  38],
#          [ 16,   3,  39]],
#
#         [[ 20,  12,  25],
#          [ 20,  12,  25],
#          [ 19,  11,  24],
#          ...,
#          [ 22,   9,  45],
#          [ 23,  10,  46],
#          [ 24,  11,  47]],
#
#         [[ 21,  13,  28],
#          [ 21,  13,  28],
#          [ 20,  11,  29],
#          ...,
#          [ 32,  18,  57],
#          [ 35,  18,  58],
#          [ 36,  19,  59]],
#
#         ...,
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
#          [182, 149, 111],
#          [182, 149, 111],
#          ...,
#          [174, 143, 105],
#          [174, 143, 105],
#          [174, 143, 105]],
#
#         [[182, 149, 111],
# ...
